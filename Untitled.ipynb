# %%
import tensorflow as tf 
tf.__version__
# Out:
# '2.1.0'

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 3410051903023037983,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 2204421324
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 14687942139014596270
#  physical_device_desc: "device: 0, name: GeForce GTX 1060 3GB, pci bus id: 0000:01:00.0, compute capability: 6.1"]

# %%
# !conda list
# Out:
# # packages in environment at C:\Users\Kang\anaconda:
# #
# # Name                    Version                   Build  Channel
# _anaconda_depends         2020.07                  py37_0
# _ipyw_jlab_nb_ext_conf    0.1.0                    py37_0
# _tflow_select             2.1.0                       gpu
# absl-py                   0.10.0                   py37_0
# aiohttp                   3.6.3            py37he774522_0
# alabaster                 0.7.12                   py37_0
# anaconda                  custom                   py37_1
# anaconda-client           1.7.2                    py37_0
# anaconda-navigator        1.9.12                   py37_0
# anaconda-project          0.8.4                      py_0
# argh                      0.26.2                   py37_0
# argon2-cffi               20.1.0           py37he774522_1
# asn1crypto                1.4.0                      py_0
# astor                     0.8.1                    py37_0
# ...
